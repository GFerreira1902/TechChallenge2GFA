# %% [markdown]
# # 04 - Avaliacao e Explicabilidade
#
# ## Objetivo
# Aprofundar o modelo principal escolhido na etapa 4 (Regressao Logistica) para responder:
# - Quao bom e o modelo final?
# - Quais variaveis mais influenciam as decisoes?
# - Por que o modelo acerta ou erra casos especificos?

# %%
import os
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import shap

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

sns.set_theme(style='whitegrid')
shap.initjs()

print('Bibliotecas carregadas com sucesso.')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Bibliotecas carregadas com sucesso.

# %% [markdown]
# ## 1. Carregar dados processados

# %%
base_path = '../data/processed'

X_train_raw = pd.read_csv(f'{base_path}/X_train_raw.csv')
X_test_raw = pd.read_csv(f'{base_path}/X_test_raw.csv')
y_train = pd.read_csv(f'{base_path}/y_train.csv').squeeze('columns')
y_test = pd.read_csv(f'{base_path}/y_test.csv').squeeze('columns')

print(f'X_train_raw: {X_train_raw.shape} | X_test_raw: {X_test_raw.shape}')
print(f'y_train: {y_train.shape} | y_test: {y_test.shape}')
# Out:
# X_train_raw: (455, 30) | X_test_raw: (114, 30)
# y_train: (455,) | y_test: (114,)

# %% [markdown]
# ## 2. Recriar scaler e modelo final
#
# Recriamos o pipeline vencedor da etapa 4 para manter consistencia: StandardScaler + Regressao Logistica.

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(
    scaler.fit_transform(X_train_raw),
    columns=X_train_raw.columns,
    index=X_train_raw.index
)
X_test_scaled = pd.DataFrame(
    scaler.transform(X_test_raw),
    columns=X_test_raw.columns,
    index=X_test_raw.index
)

model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train_scaled, y_train)

print('Pipeline recriado com sucesso.')
# Out:
# Pipeline recriado com sucesso.

# %% [markdown]
# ## 3. Metricas finais do modelo

# %%
y_pred = model.predict(X_test_scaled)
y_proba = model.predict_proba(X_test_scaled)[:, 1]

metricas = pd.DataFrame([
    {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision_maligno': precision_score(y_test, y_pred, pos_label=1),
        'recall_maligno': recall_score(y_test, y_pred, pos_label=1),
        'f1_maligno': f1_score(y_test, y_pred, pos_label=1)
    }
]).round(4)

metricas
# Out:
#    accuracy  precision_maligno  recall_maligno  f1_maligno
# 0    0.9649              0.975          0.9286      0.9512

# %%
print(classification_report(y_test, y_pred, target_names=['Benigno (0)', 'Maligno (1)']))
# Out:
#               precision    recall  f1-score   support
#
#  Benigno (0)       0.96      0.99      0.97        72
#  Maligno (1)       0.97      0.93      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
os.makedirs('../outputs/figures', exist_ok=True)

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Matriz de Confusao - Regressao Logistica')
plt.xlabel('Predito')
plt.ylabel('Real')
plt.xticks([0.5, 1.5], ['Benigno', 'Maligno'])
plt.yticks([0.5, 1.5], ['Benigno', 'Maligno'])
plt.tight_layout()
plt.savefig('../outputs/figures/matriz_confusao_logreg.png', dpi=150)
plt.show()

# %% [markdown]
# ## 4. Feature importance via coeficientes
#
# Como a Regressao Logistica foi treinada com dados padronizados, a magnitude dos coeficientes pode ser usada para comparar importancia relativa das variaveis.
#
# - Coeficiente positivo: empurra a predicao para maligno
# - Coeficiente negativo: empurra a predicao para benigno

# %%
coef_df = pd.DataFrame({
    'feature': X_train_scaled.columns,
    'coeficiente': model.coef_[0]
})
coef_df['importance_abs'] = coef_df['coeficiente'].abs()
coef_df['direcao'] = np.where(coef_df['coeficiente'] >= 0, 'Puxa para maligno', 'Puxa para benigno')
coef_df = coef_df.sort_values('importance_abs', ascending=False).reset_index(drop=True)

coef_df.head(15)
# Out:
#                  feature  coeficiente  importance_abs            direcao
# 0          texture_worst     1.434093        1.434093  Puxa para maligno
# 1              radius_se     1.233325        1.233325  Puxa para maligno
# 2         symmetry_worst     1.061264        1.061264  Puxa para maligno
# 3    concave points_mean     0.952813        0.952813  Puxa para maligno
# 4        concavity_worst     0.911406        0.911406  Puxa para maligno
# 5                area_se     0.909029        0.909029  Puxa para maligno
# 6         compactness_se    -0.906925        0.906925  Puxa para benigno
# 7             area_worst     0.900477        0.900477  Puxa para maligno
# 8           radius_worst     0.896968        0.896968  Puxa para maligno
# 9         concavity_mean     0.782298        0.782298  Puxa para maligno
# 10          perimeter_se     0.748295        0.748295  Puxa para maligno
# 11       perimeter_worst     0.723111        0.723111  Puxa para maligno
# 12  concave points_worst     0.703999        0.703999  Puxa para maligno
# 13  fractal_dimension_se    -0.593876        0.593876  Puxa para benigno
# 14          texture_mean     0.482219        0.482219  Puxa para maligno

# %%
top_features = coef_df.head(15).sort_values('coeficiente')
colors = ['#b54747' if value > 0 else '#3b6fb6' for value in top_features['coeficiente']]

plt.figure(figsize=(10, 7))
plt.barh(top_features['feature'], top_features['coeficiente'], color=colors)
plt.title('Coeficientes da Regressao Logistica (Top 15)')
plt.xlabel('Coeficiente padronizado')
plt.ylabel('Feature')
plt.tight_layout()
plt.savefig('../outputs/figures/feature_importance_logreg.png', dpi=150)
plt.show()

# %% [markdown]
# # 1. Carregando as bases de teste e o Modelo Otimizado\nVamos testar e analisar como nosso motor de inferência (Random Forest com pesos ajustados pelo GA) se comporta com o set de testes usando matrizes de explicabilidade.

# %%
explainer = shap.Explainer(model, X_train_scaled)
shap_values = explainer(X_test_scaled)

print('SHAP calculado com sucesso.')
# Out:
# SHAP calculado com sucesso.

# %%
shap.plots.bar(shap_values, max_display=15, show=False)
plt.tight_layout()
plt.savefig('../outputs/figures/shap_bar_logreg.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
shap.plots.beeswarm(shap_values, max_display=15, show=False)
plt.tight_layout()
plt.savefig('../outputs/figures/shap_beeswarm_logreg.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Analise de erros
#
# Vamos identificar falsos negativos e falsos positivos para discutir limites do modelo.

# %%
analise_erros = X_test_raw.copy()
analise_erros['y_real'] = y_test.values
analise_erros['y_pred'] = y_pred
analise_erros['prob_maligno'] = y_proba

falsos_negativos = analise_erros[(analise_erros['y_real'] == 1) & (analise_erros['y_pred'] == 0)].copy()
falsos_positivos = analise_erros[(analise_erros['y_real'] == 0) & (analise_erros['y_pred'] == 1)].copy()

resumo_erros = pd.DataFrame({
    'tipo_erro': ['Falso Negativo', 'Falso Positivo'],
    'quantidade': [len(falsos_negativos), len(falsos_positivos)]
})

resumo_erros
# Out:
#         tipo_erro  quantidade
# 0  Falso Negativo           3
# 1  Falso Positivo           1

# %%
print('Falsos negativos:')
display(falsos_negativos[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'concavity_mean', 'prob_maligno']].head())

print('Falsos positivos:')
display(falsos_positivos[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'concavity_mean', 'prob_maligno']].head())
# Out:
# Falsos negativos:
#      radius_mean  texture_mean  perimeter_mean  area_mean  concavity_mean  \
# 16         13.80         15.79           90.43      584.1         0.07789
# 87         14.22         23.12           94.37      609.9         0.19810
# 112        15.12         16.68           98.78      716.6         0.07550
#
#      prob_maligno
# 16       0.061429
# 87       0.314532
# 112      0.491610
# Falsos positivos:
#    radius_mean  texture_mean  perimeter_mean  area_mean  concavity_mean  \
# 4        13.38         30.72           86.34      557.2         0.02819
#
#    prob_maligno
# 4      0.509155

# %% [markdown]
# ## 7. SHAP local em casos especificos
#
# Vamos explicar:
# - um caso corretamente previsto como maligno
# - um falso negativo, se existir

# %%
indices_tp = analise_erros[(analise_erros['y_real'] == 1) & (analise_erros['y_pred'] == 1)].index.tolist()
indices_fn = falsos_negativos.index.tolist()

indice_tp = indices_tp[0] if indices_tp else None
indice_fn = indices_fn[0] if indices_fn else None

print(f'Indice TP selecionado: {indice_tp}')
print(f'Indice FN selecionado: {indice_fn}')
# Out:
# Indice TP selecionado: 1
# Indice FN selecionado: 16

# %%
if indice_tp is not None:
    pos_tp = X_test_scaled.index.get_loc(indice_tp)
    shap.plots.waterfall(shap_values[pos_tp], max_display=10, show=False)
    plt.tight_layout()
    plt.savefig('../outputs/figures/shap_local_true_positive.png', dpi=150, bbox_inches='tight')
    plt.show()
else:
    print('Nao foi encontrado verdadeiro positivo para explicacao local.')

# %%
if indice_fn is not None:
    pos_fn = X_test_scaled.index.get_loc(indice_fn)
    shap.plots.waterfall(shap_values[pos_fn], max_display=10, show=False)
    plt.tight_layout()
    plt.savefig('../outputs/figures/shap_local_false_negative.png', dpi=150, bbox_inches='tight')
    plt.show()
else:
    print('Nao houve falso negativo neste conjunto.')

# %% [markdown]
# ## 8. Salvar artefatos reutilizaveis

# %%
os.makedirs('../outputs/models', exist_ok=True)

joblib.dump(model, '../outputs/models/modelo_logistico_final.pkl')
joblib.dump(scaler, '../outputs/models/scaler_logistico_final.pkl')
metricas.to_csv('../outputs/models/metricas_logreg.csv', index=False)
coef_df.to_csv('../outputs/models/feature_importance_logreg.csv', index=False)
resumo_erros.to_csv('../outputs/models/resumo_erros_logreg.csv', index=False)

print('Artefatos salvos com sucesso.')
# Out:
# Artefatos salvos com sucesso.

# %% [markdown]
# ## Conclusao
#
# A etapa 5 consolida o modelo final e mostra nao apenas o desempenho, mas tambem a logica por tras das decisoes e dos erros.

# %% [markdown]
# ## 9. Ajuste controlado sem fugir do escopo
#
# Para reduzir erros criticos (falsos negativos), vamos testar somente variacoes da Regressao Logistica:
#
# - Baseline (modelo atual)
# - Regressao Logistica com `class_weight='balanced'`
# - Diferentes limiares de decisao (0.50, 0.45, 0.40, 0.35)
#
# Obs: isso continua dentro do escopo do Tech Challenge, pois foi mantido o mesmo problema e a mesma abordagem de classificacao supervisionada.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Modelo com peso balanceado para tentar reduzir falsos negativos
model_balanced = LogisticRegression(max_iter=1000, random_state=42, class_weight='balanced')
model_balanced.fit(X_train_scaled, y_train)

proba_base = model.predict_proba(X_test_scaled)[:, 1]
proba_bal = model_balanced.predict_proba(X_test_scaled)[:, 1]

thresholds = [0.50, 0.45, 0.40, 0.35]
rows = []

for t in thresholds:
    pred_base = (proba_base >= t).astype(int)
    pred_bal = (proba_bal >= t).astype(int)

    for nome, pred in [('baseline', pred_base), ('balanced', pred_bal)]:
        tn = int(((y_test == 0) & (pred == 0)).sum())
        fp = int(((y_test == 0) & (pred == 1)).sum())
        fn = int(((y_test == 1) & (pred == 0)).sum())
        tp = int(((y_test == 1) & (pred == 1)).sum())

        rows.append({
            'modelo': nome,
            'threshold': t,
            'accuracy': round(accuracy_score(y_test, pred), 4),
            'precision_maligno': round(precision_score(y_test, pred, pos_label=1, zero_division=0), 4),
            'recall_maligno': round(recall_score(y_test, pred, pos_label=1, zero_division=0), 4),
            'f1_maligno': round(f1_score(y_test, pred, pos_label=1, zero_division=0), 4),
            'falsos_negativos': fn,
            'falsos_positivos': fp,
            'tp': tp,
            'tn': tn
        })

df_tuning = pd.DataFrame(rows)

# Ordenacao priorizando menor FN, depois maior F1, depois maior recall, depois maior accuracy
df_tuning_ranked = df_tuning.sort_values(
    by=['falsos_negativos', 'f1_maligno', 'recall_maligno', 'accuracy'],
    ascending=[True, False, False, False]
).reset_index(drop=True)

df_tuning_ranked
# Out:
#      modelo  threshold  accuracy  precision_maligno  recall_maligno  \
# 0  balanced       0.50    0.9737             0.9756          0.9524
# 1  baseline       0.45    0.9737             0.9756          0.9524
# 2  balanced       0.45    0.9737             0.9756          0.9524
# 3  baseline       0.40    0.9737             0.9756          0.9524
# 4  balanced       0.40    0.9737             0.9756          0.9524
# 5  baseline       0.35    0.9737             0.9756          0.9524
# 6  balanced       0.35    0.9737             0.9756          0.9524
# 7  baseline       0.50    0.9649             0.9750          0.9286
#
#    f1_maligno  falsos_negativos  falsos_positivos  tp  tn
# 0      0.9639                 2                 1  40  71
# 1      0.9639                 2                 1  40  71
# 2      0.9639                 2                 1  40  71
# 3      0.9639                 2                 1  40  71
# 4      0.9639                 2                 1  40  71
# 5      0.9639                 2                 1  40  71
# 6      0.9639                 2                 1  40  71
# 7      0.9512                 3                 1  39  71

# %%
melhor_ajuste = df_tuning_ranked.iloc[0]
print('Melhor ajuste encontrado (criterio: menor FN, maior F1):')
print(melhor_ajuste)

plt.figure(figsize=(10, 5))
plot_df = df_tuning[df_tuning['threshold'].isin([0.50, 0.45, 0.40, 0.35])].copy()
sns.lineplot(data=plot_df, x='threshold', y='falsos_negativos', hue='modelo', marker='o')
plt.gca().invert_xaxis()
plt.title('Falsos Negativos por limiar')
plt.xlabel('Threshold (maior para menor)')
plt.ylabel('Quantidade de falsos negativos')
plt.tight_layout()
os.makedirs('../outputs/figures', exist_ok=True)
plt.savefig('../outputs/figures/tuning_falsos_negativos_logreg.png', dpi=150)
plt.show()
# Out:
# Melhor ajuste encontrado (criterio: menor FN, maior F1):
# modelo               balanced
# threshold                 0.5
# accuracy               0.9737
# precision_maligno      0.9756
# recall_maligno         0.9524
# f1_maligno             0.9639
# falsos_negativos            2
# falsos_positivos            1
# tp                         40
# tn                         71
# Name: 0, dtype: object

# %%
os.makedirs('../outputs/models', exist_ok=True)
df_tuning_ranked.to_csv('../outputs/models/tuning_logreg_threshold_classweight.csv', index=False)
print('Tabela de tuning salva em outputs/models/tuning_logreg_threshold_classweight.csv')
# Out:
# Tabela de tuning salva em outputs/models/tuning_logreg_threshold_classweight.csv

# %%
# Persistir modelo ajustado vencedor da tentativa de correcao
joblib.dump(model_balanced, '../outputs/models/modelo_logistico_tuned_balanced.pkl')

melhor_ajuste_df = pd.DataFrame([melhor_ajuste])
melhor_ajuste_df.to_csv('../outputs/models/melhor_ajuste_logreg.csv', index=False)

print('Modelo tuned salvo em outputs/models/modelo_logistico_tuned_balanced.pkl')
print('Resumo do melhor ajuste salvo em outputs/models/melhor_ajuste_logreg.csv')
# Out:
# Modelo tuned salvo em outputs/models/modelo_logistico_tuned_balanced.pkl
# Resumo do melhor ajuste salvo em outputs/models/melhor_ajuste_logreg.csv

# %% [markdown]
# # Integração do Modelo Genético com LLM Explicável (LLaMA-3)
# Este notebook demonstra a junção entre a saída fria e matemática do modelo de Machine Learning (Random Forest) - já otimizado na etapa anterior com Algoritmos Genéticos - sendo enviada e interpretada por uma Inteligência Artificial Generativa (Llama 3 via Groq).
#
# *Atende ao Requisito do Edital: Gerar explicações em linguagem natural com contexto social e linguagem sensível e preparar base para Fine-Tuning.*

# %%
import sys
import os
import joblib
import pandas as pd
import numpy as np

sys.path.append(os.path.abspath('../src'))
from llm_explainer import MedicalLLMExplainer

# 1. Carregando as bases de teste da Fase 1 e o Modelo Otimizado
X_test = pd.read_csv('../data/processed/X_test_scaled.csv')
y_test = pd.read_csv('../data/processed/y_test.csv').squeeze()

# Vamos pegar 3 pacientes hipotéticas da nossa base de testes
samples_idx = [0, 5, 20] # Troque os índices se quiser paciente diferente
pacientes = X_test.iloc[samples_idx]
pacientes_real = y_test.iloc[samples_idx]

# Carregando o Super Modelo Random Forest "Sobrevivente" do GA (Gerado no notebook otimizacao_ga)
# Se der erro aqui, garanta que você rodou todas as celulas do notebook otimizacao_ga.ipynb primeiro!
modelo_ga = joblib.load('../outputs/models/best_rf_model_ga.pkl')

print("Dados e Modelos carregados com sucesso!")
# Out:
# Dados e Modelos carregados com sucesso!

# %%
# 2. Fazendo as Predições e Pegando Feature Importance
predicoes = modelo_ga.predict(pacientes)
probabilidades = modelo_ga.predict_proba(pacientes)

# Extraindo as top 3 features mais importantes desse Random Forest
importancias = modelo_ga.feature_importances_
top_indices = np.argsort(importancias)[::-1][:3]
top_features_names = X_test.columns[top_indices].tolist()

print(f"Features de maior peso na decisão da IA: {top_features_names}")
# Out:
# Features de maior peso na decisão da IA: ['area_worst', 'perimeter_worst', 'concave points_worst']

# %%
# 3. Conectando com a LLM para Explicabilidade (Laudo Sensível)

# Importando dotenv para carregar a chave de API de forma segura
from dotenv import load_dotenv
load_dotenv() # Isso vai procurar o arquivo .env (que não vai pro github)

# Usando a classe que criamos em src/
explainer = MedicalLLMExplainer()

for i, (idx, pred, proba) in enumerate(zip(samples_idx, predicoes, probabilidades)):
    confianca = proba[pred] * 100
    
    print(f"\n=======================================================")
    print(f"📋 GERANDO LAUDO PARA PACIENTE (Linha {idx} do dataset)")
    print(f"Status Real no dataset: {'Maligno (1)' if pacientes_real.iloc[i] == 1 else 'Benigno (0)'}")
    print(f"Predição via GA: {'Maligno (1)' if pred == 1 else 'Benigno (0)'} | Confiança: {confianca:.1f}%")
    print(f"Processando IA Lexical Llama-3...\n")
    
    # FORMATANDO AS FEATURES PARA O PROMPT
    # Passamos os nomes das variáveis mais impactantes e o valor delas no exame da paciente específica
    features_texto = ", ".join([f"{col} = {pacientes.iloc[i][col]:.2f}" for col in top_features_names])
    
    # Chama a API
    laudo_texto = explainer.generate_explanation(
        prediction_class=pred, 
        confidence=confianca, 
        top_features=features_texto
    )
    
    print(laudo_texto)
    print("=======================================================\n")
# Out:
# =======================================================
# 📋 GERANDO LAUDO PARA PACIENTE (Linha 0 do dataset)
# Status Real no dataset: Benigno (0)
# Predição via GA: Benigno (0) | Confiança: 99.5%
# Processando IA Lexical Llama-3...
#
# **Relatório de Explicabilidade do Rastreio de Câncer de Mama**
#
# Prezada(a) paciente,
#
# É com grande cuidado e atenção que apresentamos os resultados do seu exame de mamografia, analisado por nosso modelo de Machine Learning especializado. O objetivo deste relatório é fornecer uma visão clara e compreensível dos achados, apoiando assim a tomada de decisão médica.
#
# **Resultados do Exame:**
# O modelo de Machine Learning classificou o seu exame como **rastreio compatível com achado benigno**, com uma confiança de **99.47%**. Isso significa que, com base nas características celulares analisadas, o modelo sugere que as alterações observadas têm uma alta probabilidade de serem benignas.
#
# **Principais Variáveis que Influenciaram a Decisão:**
# As principais variáveis celulares que contribuíram para essa classificação foram:
# - **Área da lesão mais grave (area_worst)**: Um valor de **-0.65** sugere que a área da lesão não apresenta características típicas de câncer.
# - **Perímetro da lesão mais grave (perimeter_worst)**: Um valor de **-0.71** indica que o perímetro da lesão também não apresenta características sugestivas de malignidade.
# - **Pontos côncavos da lesão mais grave (concave points_worst)**: Um valor de **-0.39** reforça a ideia de que a lesão não apresenta os padrões típicos de câncer.
#
# **Interpretação e Próximos Passos:**
# Considerando esses resultados, é importante lembrar que, embora o modelo indique uma alta probabilidade de o achado ser benigno, **não é um diagnóstico definitivo**. É fundamental discutir esses resultados com seu médico mastologista ou ginecologista, que poderá avaliar a necessidade de **novos exames** ou **monitoramento** para confirmar a natureza da lesão.
#
# **Conclusão:**
# Este relatório visa apoiar a tomada de decisão médica, oferecendo uma visão detalhada dos achados do exame de mamografia. Lembre-se de que a comunicação aberta com seu médico é crucial para entender completamente os resultados e planejar os próximos passos.
#
# Atenciosamente,
# Assistente de Inteligência Artificial em Saúde da Mulher
# =======================================================
#
#
# =======================================================
# 📋 GERANDO LAUDO PARA PACIENTE (Linha 5 do dataset)
# Status Real no dataset: Benigno (0)
# Predição via GA: Benigno (0) | Confiança: 88.7%
# Processando IA Lexical Llama-3...
#
# **Relatório de Explicabilidade do Rastreio de Câncer de Mama**
#
# Prezado(a) Médico(a) Mastologista/Ginecologista,
#
# Este relatório tem como objetivo fornecer uma explicação detalhada e acessível sobre os resultados do modelo de Machine Learning aplicado ao exame de mamografia da paciente. O objetivo é apoiar a tomada de decisão clínica com informações claras e precisas.
#
# **Resultado do Rastreio:**
# O modelo de Machine Learning indica um resultado compatível com um achado provável benigno, com uma confiança do algoritmo de 88,75%. Este resultado sugere que as características celulares analisadas não apresentam indícios significativos de câncer de mama.
#
# **Principais Variáveis Celulares:**
# As principais variáveis celulares que contribuíram para esta decisão foram:
# - **Área Worst (area_worst = -1,02):** Esta variável se refere à medida da área da lesão mais suspeita observada na mamografia. O valor negativo indica que a área da lesão é menor do que a média, o que pode ser um indicador de benignidade.
# - **Perímetro Worst (perimeter_worst = -1,15):** O perímetro da lesão mais suspeita também foi considerado. O valor negativo sugere que o perímetro é menor do que o esperado para lesões malignas, reforçando a hipótese de um achado benigno.
# - **Pontos Concavos Worst (concave points_worst = -0,01):** Esta variável avalia a presença de pontos concavos na lesão, que podem ser indicativos de malignidade. O valor muito próximo de zero sugere que não há uma quantidade significativa de pontos concavos, o que apoia a classificação como benigno.
#
# **Interpretação e Recomendações:**
# Considerando os resultados e as variáveis celulares analisadas, é importante realizar um acompanhamento cuidadoso para confirmar a natureza benigna da lesão. Recomenda-se:
# - **Acompanhamento com exames de imagem:** Realizar novos exames de mamografia em intervalos regulares para monitorar qualquer mudança na lesão.
# - **Avaliação clínica:** Realizar uma avaliação clínica detalhada para verificar se há qualquer alteração nos sintomas ou no exame físico da paciente.
# - **Biópsia (se necessário):** Se houver qualquer mudança nos exames de imagem ou se a lesão apresentar características suspeitas, pode ser necessário realizar uma biópsia para obter um diagnóstico definitivo.
#
# **Conclusão:**
# O resultado do modelo de Machine Learning sugere um achado provável benigno, com base nas características celulares analisadas. No entanto, é fundamental realizar um acompanhamento cuidadoso e considerar a realização de exames adicionais para confirmar a natureza da lesão.
#
# Atenciosamente,
# Assistente de Inteligência Artificial em Saúde da Mulher
# =======================================================
#
#
# =======================================================
# 📋 GERANDO LAUDO PARA PACIENTE (Linha 20 do dataset)
# Status Real no dataset: Benigno (0)
# Predição via GA: Benigno (0) | Confiança: 98.2%
# Processando IA Lexical Llama-3...
#
# **Relatório de Explicabilidade do Rastreio de Câncer de Mama**
#
# Prezado(a) Médico(a) Mastologista/Ginecologista,
#
# Este relatório tem como objetivo fornecer uma interpretação detalhada e humanizada dos resultados obtidos pelo modelo de Machine Learning aplicado aos exames de mamografia da paciente. O objetivo é apoiar a tomada de decisão clínica, ressaltando a importância de um acompanhamento personalizado e sensível às necessidades de saúde da mulher.
#
# **Resultado do Rastreio:**
# O modelo de Machine Learning indicou um resultado **rastreio compatível com achado benigno**, com uma confiança do algoritmo de **98,19%**. Este resultado sugere que as características celulares observadas nos exames de mamografia são mais compatíveis com lesões benignas do que com lesões malignas.
#
# **Principais Variáveis Celulares:**
# As principais variáveis celulares que contribuíram para esta decisão foram:
# - **area_worst = -0,93**: Indica que a área da lesão é menor do que o esperado para lesões malignas, o que apoia a classificação benigna.
# - **perimeter_worst = -1,17**: Sugere que o perímetro da lesão é mais regular e menos irregular do que o observado em lesões malignas, reforçando a probabilidade de um achado benigno.
# - **concave points_worst = -1,00**: Este valor indica a presença de menos pontos côncavos na lesão, o que é característico de lesões benignas, que tendem a ter contornos mais regulares.
#
# **Interpretação e Recomendações:**
# Considerando os resultados e as variáveis celulares que os influenciaram, é importante realizar um **acompanhamento clínico** para confirmar a natureza benigna da lesão. Embora o modelo indique uma alta probabilidade de achado benigno, é fundamental lembrar que nenhum resultado de rastreio substitui a avaliação clínica completa e o julgamento médico especializado.
#
# **Próximos Passos:**
# Recomenda-se:
# - **Acompanhamento com exames de imagem** em intervalos regulares para monitorar qualquer mudança na lesão.
# - **Avaliação clínica** detalhada para considerar outros fatores de risco e histórico médico da paciente.
# - **Biópsia**, se necessário, com base na evolução da lesão ou em alterações nos sintomas da paciente.
#
# **Conclusão:**
# Este relatório visa apoiar a tomada de decisão clínica, oferecendo uma visão detalhada dos resultados do modelo de Machine Learning. É essencial que os resultados sejam interpretados no contexto de uma avaliação clínica completa, considerando todos os aspectos relevantes da saúde da paciente.
#
# Atenciosamente,
# Assistente de Inteligência Artificial em Saúde da Mulher
# =======================================================

# %%
import json

# 4. Validando se a Base Histórica está sendo gerada para a Fase 3
history_path = '../outputs/llm_history.json'

if os.path.exists(history_path):
    with open(history_path, 'r', encoding='utf-8') as f:
        historico = json.load(f)
    print(f"✅ Base de dados histórica para Fine-tuning existe e contém {len(historico)} laudos gerados.")
else:
    print("❌ Arquivo de histórico não encontrado.")
